# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

file = "./Data/maylake1.csv"
df = pd.read_csv(file)

x = df["X"]
y = df["Y"]
z = df["Z"]

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

triangles = ax.plot_trisurf(x,y,z, cmap="viridis", edgecolor="none", alpha=0.8)


ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
ax.set_zlabel("z axis")

fig.colorbar(triangles, ax=ax, shrink=0.5)

ax.view_init(elev=30, azim=0)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10932\2385654302.py in <module>
#      28 z_height = 968
#      29 X, Y = x, y
# ---> 30 ax.plot_surface(X,Y,z_height,color="red", alpha=0.5)
#      31
#      32 ax.view_init(elev=30, azim=0)
#
# c:\Users\itoka\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# c:\Users\itoka\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1578         had_data = self.has_data()
#    1579
# -> 1580         if Z.ndim != 2:
#    1581             raise ValueError("Argument Z must be 2-dimensional.")
#    1582
#
# AttributeError: 'int' object has no attribute 'ndim'
