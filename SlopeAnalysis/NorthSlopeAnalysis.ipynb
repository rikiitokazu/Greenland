# %%
# !pip install import-ipynb

import import_ipynb
import SouthSlopeAnalysis

SouthSlopeAnalysis.volume_graphs("./Data/north_volumes.csv", "North_X", "May_NY")
SouthSlopeAnalysis.volume_graphs("./Data/north_volumes.csv", "North_X", "Aug_NY")
SouthSlopeAnalysis.volume_graphs("./Data/north_volumes.csv", "North_X", "Mosaic_NY")
# Out:
# R-squared: 0.9851843627839137
# R-squared: 0.9886218862387601
# R-squared: 0.9119324350943876
