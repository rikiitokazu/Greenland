# %%
# ----- MAKE A COPY OF THIS -----

# Description: Use data calculated to create graph
# Specific for current directory

# %%
def print_entire_table(year, sig):
    #path =  net + f"/{project}/Graphs/graph{year}.png"
    
    df = pd.read_csv("./main.csv")
    df = df[df["Year"] == int(year)]
    y_actual = df["Y"][df["Type"] == "Actual"]
    y_sig = df["Y"][(df["Type"] == "Kmeans") & (df["Bin"] == -1)]

    print(len(y_actual))
    print(len(y_sig))
    dates = df["X"][df["Year"] == int(year)]
    dates = dates.drop_duplicates()
    
    # Convert temporarily to string
    temp = []
    for date in dates:
        temp.append(str(date))
    
        
    x = []
    for date in temp:
        formatted_date = datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")
        x.append(formatted_date)
    dates = pd.to_datetime(x)
    
    plt.figure(figsize=(10, 6))
    plt.plot(dates, y_actual, marker='o', linestyle='-', label = "Actual")
    plt.plot(dates, y_sig, marker = 'o', linestyle = '-', label = sig)
    
    
    date_labels = pd.date_range(f"{year}-06-05", f"{year}-08-31", 10)
    plt.xticks(date_labels, [date.strftime("%Y-%m-%d") for date in date_labels], rotation=45)
    plt.title(f"Graph for {year}")
    plt.xlabel("Dates")

    plt.ylabel("Percentage covered in water")
    #plt.savefig(path)
    plt.legend() 
    plt.show()

# %%
def print_bin(year, sig, bin, elevation, num):
    #path =  net + f"/{project}/Graphs/graph{year}.png"
    
    df = pd.read_csv("./main.csv")
    df = df[df["Year"] == int(year)]
    y = df["Y"][(df["Type"] == "Kmeans") & (df["Bin"] == bin) & (df["Bands"] == "9")]

    dates = df["X"][df["Year"] == int(year)]
    dates = dates.drop_duplicates()
    
    # Convert temporarily to string
    temp = []
    for date in dates:
        temp.append(str(date))
    
        
    x = []
    for date in temp:
        formatted_date = datetime.strptime(date, "%Y%m%d").strftime("%Y-%m-%d")
        x.append(formatted_date)
    dates = pd.to_datetime(x)
    
    plt.figure(figsize=(20, 40))
    plt.subplot(4, 1, num)
    plt.plot(dates, y, marker='o', linestyle='-', label = "Actual")
    
    date_labels = pd.date_range(f"{year}-06-05", f"{year}-08-31", 10)
    plt.xticks(date_labels, [date.strftime("%Y-%m-%d") for date in date_labels], rotation=45)
    plt.title(f"Graph for elevation at {elevation} meters")
    plt.xlabel("Dates")
    
    plt.yticks([i/8 for i in range(21)])
    plt.ylabel("Percentage covered in water")
    #plt.savefig(path)
    plt.legend()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

bins = ["800-950", "950-1100", "1100-1250", "1250-1400"]

for i in range(4):
    print_bin("2020", "Kmeans", i+1, bins[i], i+1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

bins = ["800-950", "950-1100", "1100-1250", "1250-1400"]

for i in range(4):
    print_bin("2020", "Kmeans", i+1, bins[i], i+1)

# %%
print_entire_table("2020", "Kmeans")
# Out:
# 9
# 9
